# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
# https://www.kaggle.com/jneupane12/movielens
movies = pd.read_csv('movies.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27278 entries, 0 to 27277
# Data columns (total 3 columns):
# movieId    27278 non-null int64
# title      27278 non-null object
# genres     27278 non-null object
# dtypes: int64(1), object(2)
# memory usage: 639.4+ KB

# %%
print('无重复ID:', len(movies.movieId.value_counts()) == len(movies))
# Out:
# 无重复ID: True

# %%
# 将genres进行one-hot编码（离散特征有多少取值，就用多少维来表示这个特征）
movies_hot_encoded = movies.drop('genres',1).join(movies.genres.str.get_dummies())
# 将movieId, title设置为index
movies_hot_encoded.set_index(['movieId','title'],inplace=True)
# 挖掘频繁项集，最小支持度为0.02
itemsets = apriori(movies_hot_encoded,use_colnames=True, min_support=0.02)
# 根据频繁项集计算关联规则，设置最小提升度为2
rules =  association_rules(itemsets, metric='lift', min_threshold=2)

# %%
itemsets.sort_values(by='support', ascending=False)
# Out:
#      support                  itemsets
# 7   0.489185                   (Drama)
# 4   0.306987                  (Comedy)
# 14  0.153164                (Thriller)
# 12  0.151294                 (Romance)
# 0   0.129042                  (Action)
# 5   0.107743                   (Crime)
# 9   0.095718                  (Horror)
# 31  0.094325          (Romance, Drama)
# 26  0.093335           (Drama, Comedy)
# 6   0.090586             (Documentary)
# 1   0.085380               (Adventure)
# 27  0.069470         (Romance, Comedy)
# 32  0.068480         (Thriller, Drama)
# 13  0.063898                  (Sci-Fi)
# 28  0.062761            (Drama, Crime)
# 11  0.055503                 (Mystery)
# 8   0.051763                 (Fantasy)
# 29  0.045165         (Thriller, Crime)
# 20  0.044101           (Drama, Action)
# 15  0.043772                     (War)
# 3   0.041755                (Children)
# 22  0.040655        (Thriller, Action)
# 34  0.039336        (Thriller, Horror)
# 10  0.037979                 (Musical)
# 2   0.037649               (Animation)
# 17  0.035633       (Action, Adventure)
# 33  0.032774              (Drama, War)
# 35  0.029144       (Thriller, Mystery)
# 19  0.028118           (Crime, Action)
# 36  0.027458  (Romance, Drama, Comedy)
# 30  0.026432          (Drama, Mystery)
# 18  0.026358          (Comedy, Action)
# 25  0.025368           (Comedy, Crime)
# 24  0.025295        (Drama, Adventure)
# 37  0.024965  (Thriller, Drama, Crime)
# 16  0.024782                 (Western)
# 21  0.023499          (Action, Sci-Fi)
# 23  0.022032       (Comedy, Adventure)

# %%
rules.sort_values(by='lift', ascending=False)
# Out:
#           antecedents        consequents  antecedent support  \
# 13          (Mystery)         (Thriller)            0.055503
# 12         (Thriller)          (Mystery)            0.153164
# 17            (Crime)  (Thriller, Drama)            0.107743
# 14  (Thriller, Drama)            (Crime)            0.068480
# 1         (Adventure)           (Action)            0.085380
# 0            (Action)        (Adventure)            0.129042
# 5            (Sci-Fi)           (Action)            0.063898
# 4            (Action)           (Sci-Fi)            0.129042
# 8          (Thriller)            (Crime)            0.153164
# 9             (Crime)         (Thriller)            0.107743
# 10         (Thriller)           (Horror)            0.153164
# 11           (Horror)         (Thriller)            0.095718
# 15     (Drama, Crime)         (Thriller)            0.062761
# 16         (Thriller)     (Drama, Crime)            0.153164
# 7            (Action)         (Thriller)            0.129042
# 6          (Thriller)           (Action)            0.153164
# 3            (Action)            (Crime)            0.129042
# 2             (Crime)           (Action)            0.107743
#
#     consequent support   support  confidence      lift  leverage  conviction
# 13            0.153164  0.029144    0.525099  3.428352  0.020643    1.783185
# 12            0.055503  0.029144    0.190282  3.428352  0.020643    1.166453
# 17            0.068480  0.024965    0.231711  3.383632  0.017587    1.212461
# 14            0.107743  0.024965    0.364561  3.383632  0.017587    1.404159
# 1             0.129042  0.035633    0.417347  3.234198  0.024616    1.494813
# 0             0.085380  0.035633    0.276136  3.234198  0.024616    1.263525
# 5             0.129042  0.023499    0.367757  2.849906  0.015253    1.377568
# 4             0.063898  0.023499    0.182102  2.849906  0.015253    1.144523
# 8             0.107743  0.045165    0.294878  2.736877  0.028662    1.265394
# 9             0.153164  0.045165    0.419190  2.736877  0.028662    1.458027
# 10            0.095718  0.039336    0.256821  2.683100  0.024675    1.216776
# 11            0.153164  0.039336    0.410954  2.683100  0.024675    1.437639
# 15            0.153164  0.024965    0.397780  2.597093  0.015352    1.406192
# 16            0.062761  0.024965    0.162997  2.597093  0.015352    1.119755
# 7             0.153164  0.040655    0.315057  2.056994  0.020891    1.236360
# 6             0.129042  0.040655    0.265438  2.056994  0.020891    1.185684
# 3             0.107743  0.028118    0.217898  2.022393  0.014215    1.140845
# 2             0.129042  0.028118    0.260973  2.022393  0.014215    1.178520
